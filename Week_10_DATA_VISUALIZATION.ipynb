# %% [markdown]
# # Week 10: Data Visualization with Seaborn
#
# This notebook answers the 15 Seaborn syntax questions from the prompt.

# %%
# 1) Import Seaborn
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Example DataFrame used for syntax demonstrations
np.random.seed(42)
df = pd.DataFrame({
    "x": np.random.randn(200),
    "y": np.random.randn(200) * 2 + 1,
    "group": np.random.choice(["A", "B", "C"], size=200)
})

df.head()
# Out:
#           x         y group
# 0  0.496714  1.715575     C
# 1 -0.138264  2.121569     C
# 2  0.647689  3.166102     A
# 3  1.523030  3.107604     A
# 4 -0.234153 -1.755339     C

# %%
# 2) Scatter plot for x and y in DataFrame df
ax = sns.scatterplot(data=df, x="x", y="y")
plt.show()

# 3) Line plot for x and y in DataFrame df
ax = sns.lineplot(data=df, x="x", y="y")
plt.show()

# 4) Histogram for x in DataFrame df
ax = sns.histplot(data=df, x="x")
plt.show()

# 5) Stacked histogram for x with hue y-like category (using 'group' as categorical hue)
ax = sns.histplot(data=df, x="x", hue="group", multiple="stack")
plt.show()

# 6) Heatmap for variables x and y (correlation heatmap)
ax = sns.heatmap(df[["x", "y"]].corr(), annot=True, cmap="Blues")
plt.show()

# 7) Box plot for x and y in DataFrame df
# (x is categorical, y is numeric)
ax = sns.boxplot(data=df, x="group", y="y")
plt.show()

# 8) Violin plot for x and y in DataFrame df
ax = sns.violinplot(data=df, x="group", y="y")
plt.show()

# 9) Bar plot for x and y in DataFrame df
ax = sns.barplot(data=df, x="group", y="y")
plt.show()

# 10) Add a title to a Seaborn plot assigned to ax
ax = sns.scatterplot(data=df, x="x", y="y")
ax.set_title("My Title")
plt.show()

# 11) Save a Seaborn plot ax to output.png
ax.figure.savefig("output.png", dpi=300, bbox_inches="tight")

# 12) Set x and y axis labels for ax
ax.set_xlabel("X Label")
ax.set_ylabel("Y Label")
plt.show()

# 13) Change color palette to Blues
sns.set_palette("Blues")
ax = sns.barplot(data=df, x="group", y="y")
plt.show()

# 14) Display a Seaborn plot with logarithmic scale on the y-axis
ax = sns.scatterplot(data=df, x="x", y="y")
ax.set_yscale("log")
plt.show()

# 15) Add a regression line to a scatter plot for x and y in DataFrame df
ax = sns.regplot(data=df, x="x", y="y")
plt.show()

# %% [markdown]
# ## Quick Reference Syntax
#
# 1. `import seaborn as sns`
# 2. `sns.scatterplot(data=df, x="x", y="y")`
# 3. `sns.lineplot(data=df, x="x", y="y")`
# 4. `sns.histplot(data=df, x="x")`
# 5. `sns.histplot(data=df, x="x", hue="y", multiple="stack")`
# 6. `sns.heatmap(df[["x", "y"]].corr(), annot=True)`
# 7. `sns.boxplot(data=df, x="x", y="y")`
# 8. `sns.violinplot(data=df, x="x", y="y")`
# 9. `sns.barplot(data=df, x="x", y="y")`
# 10. `ax.set_title("My Title")`
# 11. `ax.figure.savefig("output.png")`
# 12. `ax.set_xlabel("X Label"); ax.set_ylabel("Y Label")`
# 13. `sns.set_palette("Blues")`
# 14. `ax.set_yscale("log")`
# 15. `sns.regplot(data=df, x="x", y="y")`
