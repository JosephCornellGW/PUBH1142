# %% [markdown]
# ![Milken](GW_Milken_LOGO.jpg){width=600px}{height=150px}

# %% [markdown]
# <h1><span style="color:Steelblue">Computer Languages</span></h1>

# %% [markdown]
# <h2><span style="color:SteelBlue">Joseph Cornell</span></h2>

# %% [markdown]
# ## **Quiz Questions**

# %% [markdown]
# *Question 1: What is the purpose of an Integrated Development Environment (IDE)?*
#
# > Answer:
# >- An IDE is a software application ussed to write, test, and debug code in one place.
# >- It combines a code editor, debugger, compiler/interpreter, and other development tools.
# >- It improves efficiency by organizing the programming workflow in a single interface.

# %% [markdown]
# *Question 2: Which popular Python library is specifically designed for numerical and scientific computing?*
#
# >Answer:
# >- Numpy
# >- Provides support for arrays and matrices
# >- Includes mathematical functions for numerical computation
# >- Forms the foundation for many other scientific libraries

# %% [markdown]
# *Question 3: What is the purpose of the pandas library in Python?*
#
# > Answer:
# >- Used for data manipulation and analysis
# >- Provides DataFrame and Series data structures
# >- Useful for cleaning, transforming, and analyzing structured data
# >- Commonly used in data science and public health research

# %% [markdown]
# *Question 4: Name the deep learning framework developed by Google.*
#
# > Answer: TensorFlow

# %% [markdown]
# *Question 5: Which Python library is commonly used for data visualization?*
#
# > Answer:
# >- Matplotlib
# >- Seaborn (Built on Matplotlib)

# %% [markdown]
# *Question 6: What is the main purpose of the stats module in the SciPy library?*
#
# > Answer:
# >- Provides statistical functions and probability distributions
# >- Used for hypothesis testing
# >- Performs statistical analysis such as t-tests and correlations

# %% [markdown]
# *Question 7: Name the popular Python library that offers a flexible and dynamic computational graph.*
#
# > Answer: Pytorch

# %% [markdown]
# *Question 8: Which integrated development environment (IDE) is known for its interactive web-based interface and support for multiple programming languages?*
#
# > Answer: Jupyter Notebook

# %% [markdown]
# *Question 9: Which IDE is developed by JetBrains and offers a wide range of tools and features specifically for Python development?*
#
# > Answer: PyCharm

# %% [markdown]
# *Question 10: What is the purpose of Google Colab?*
#
# > Answer:
# >- A cloud based Jupyter notebook environment
# >- Allows users to write and run Python code in the browser

# %% [markdown]
# *Question 11: Which Python library is used for machine learning and offers a wide range of algorithms and tools?*
#
# > Answer:
# >- Scikit-learn
# >- Provides tools for classification, regression, clustering, and model evaluation

# %% [markdown]
# *Question 12: What is the purpose of the TensorFlow library?*
#
# >Answer:
# >- Used for building and training machine learning and deep learning models
# >- Supports neural networks and large-scale computation
# >- Often used in artifical intelligence applications

# %% [markdown]
# *Question 13: Name the lightweight and highly customizable IDE that gained popularity among Python developers.*
#
# > Answer: Visual Studio Code (VS Code)

# %% [markdown]
# *Question 14: Which Python library is specifically designed for scientific computing and data analysis?*
#
# > Answer: SciPy

# %% [markdown]
# *Question 15: Which library provides a MATLAB-like interface and is designed for scientific computing with Python?*
#
# > Answer:
# >- SciPy (Especially its high-level modules)
# >- Built on top of NumPy
